# %%
from home.forms import UserSignUpForm
from bootstrap4.templatetags.bootstrap4 import bootstrap_form
form = UserSignUpForm()
print(bootstrap_form(form,layout='horizontal'))
# Out:
# <div class="form-group required_fields row"><label class="col-md-3 col-form-label" for="id_username">Username</label><div class="col-md-9"><input type="text" name="username" maxlength="150" autofocus class="form-control" title="Required. 150 characters or fewer. Letters, digits and @/./+/-/_ only." required id="id_username">
#     <small class="form-text text-muted">Required. 150 characters or fewer. Letters, digits and @/./+/-/_ only.</small>
#
# </div></div>
# <div class="form-group required_fields row"><label class="col-md-3 col-form-label" for="id_school_name">School name</label><div class="col-md-9"><input type="text" name="school_name" maxlength="200" class="form-control" title="" required id="id_school_name"></div></div>
# <div class="form-group required_fields row"><label class="col-md-3 col-form-label" for="id_email">Email address</label><div class="col-md-9"><input type="email" name="email" maxlength="254" class="form-control" title="" required id="id_email"></div></div>
# ...

# %%
from home.forms import UserSignUpForm
form = UserSignUpForm()
form
# Out:
# <UserSignUpForm bound=False, valid=Unknown, fields=(username;school_name;email;mobile;city;district;state;country;pin_code;password1;password2)>

# %%
from home.forms import UserSignUpForm
from bootstrap4.templatetags.bootstrap4 import bootstrap_form
form = UserSignUpForm()
form.is_valid()
print(form.as_p())
# Out:
# <p><label for="id_username">Username:</label> <input type="text" name="username" maxlength="150" autofocus required id="id_username"> <span class="helptext">Required. 150 characters or fewer. Letters, digits and @/./+/-/_ only.</span></p>
# <p><label for="id_school_name">School name:</label> <input type="text" name="school_name" maxlength="200" required id="id_school_name"></p>
# <p><label for="id_email">Email address:</label> <input type="email" name="email" maxlength="254" required id="id_email"></p>
# <p><label for="id_mobile">Mobile:</label> <input type="text" name="mobile" maxlength="15" required id="id_mobile"></p>
# ...

# %%
packages = Package.objects.all()
packages
# Out:
# --------------------------------------------------------------------------------------------------------------
# 2021-04-24 16:20:05,598
# XXXDEBUGXXX debug_sql() /home/simha/app/.venv/lib/python3.7/site-packages/django/db/backends/utils.py[:128] django.db.backends
# []
# --------------------------------------------------------------------------------------------------------------
#
#
#
# [0.241]
# SELECT "home_package"."id",
#        "home_package"."pkg_name",
#        "home_package"."pkg_price"
# FROM "home_package"
# LIMIT 21
# --------------------------------------------------------------------------------------------------------------
# <QuerySet [<Package: Pre Nursery>, <Package: Nursery>, <Package: LKG>, <Package: UKG>, <Package: ALL CLASSES>]>

# %%
from users.models import User
user = User.objects.get(username='krishna')
user.set_password('krishna')
user.save()
# Out:
# --------------------------------------------------------------------------------------------------------------
# 2021-04-25 04:41:42,687
# XXXDEBUGXXX debug_sql() /home/simha/app/.venv/lib/python3.7/site-packages/django/db/backends/utils.py[:128] django.db.backends
# []
# --------------------------------------------------------------------------------------------------------------
#
#
#
# [0.082]
# SELECT "users_user"."id",
#        "users_user"."password",
#        "users_user"."last_login",
#        "users_user"."is_superuser",
#        "users_user"."username",
#        "users_user"."first_name",
#        "users_user"."last_name",
#        "users_user"."is_staff",
#        "users_user"."is_active",
#        "users_user"."date_joined",
#        "users_user"."school_name",
#        "users_user"."mobile",
#        "users_user"."email",
#        "users_user"."updated_at"
# FROM "users_user"
# WHERE "users_user"."username" = 'krishna'
# LIMIT 21
# ...

# %%
import random
objs  = SubTopic.objects.all()
for obj in objs:
    explains = Explain.objects.filter(SubTopic=obj)[:random.randint(1,2)]
    for explain in explains:
        explain.freeForAll = True
        explain.save()
# Out:
# --------------------------------------------------------------------------------------------------------------
# 2021-04-25 05:40:36,520
# XXXDEBUGXXX debug_sql() /home/simha/app/.venv/lib/python3.7/site-packages/django/db/backends/utils.py[:128] django.db.backends
# []
# --------------------------------------------------------------------------------------------------------------
#
#
#
# [0.082]
# SELECT "home_subtopic"."id",
#        "home_subtopic"."topic_id",
#        "home_subtopic"."SubTopicName",
#        "home_subtopic"."subtopicTitle",
#        "home_subtopic"."freeForAll"
# FROM "home_subtopic"
# --------------------------------------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------------------------------------
# 2021-04-25 05:40:36,599
# XXXDEBUGXXX debug_sql() /home/simha/app/.venv/lib/python3.7/site-packages/django/db/backends/utils.py[:128] django.db.backends
# ...

# %%
from users.models import User
user = User.objects.get(username='krishna')
user.set_password('krishna_108')
user.save()
# Out:
# --------------------------------------------------------------------------------------------------------------
# 2021-05-20T16:56:49.744+05:30
# XXXDEBUGXXX debug_sql() /home/simha/app/.venv/lib/python3.7/site-packages/django/db/backends/utils.py[:128] django.db.backends
# []
# --------------------------------------------------------------------------------------------------------------
#
#
#
# [0.002]
# SELECT "users_user"."id",
#        "users_user"."password",
#        "users_user"."last_login",
#        "users_user"."is_superuser",
#        "users_user"."username",
#        "users_user"."first_name",
#        "users_user"."last_name",
#        "users_user"."is_staff",
#        "users_user"."is_active",
#        "users_user"."date_joined",
#        "users_user"."school_name",
#        "users_user"."mobile",
#        "users_user"."email",
#        "users_user"."phone",
#        "users_user"."country",
#        "users_user"."state",
#        "users_user"."district",
# ...
